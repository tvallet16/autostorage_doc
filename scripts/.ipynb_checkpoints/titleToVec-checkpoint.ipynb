# %%
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from textScrapper import TextScrapper
from tqdm import tqdm
import os
import re
import warnings
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %%
def cleanText(final_text):
    
    final_text = re.sub(r"[^A-Za-z0-9(),!.?\'\`]", " ", final_text )
    final_text = re.sub(r"\'s", " 's ", final_text )
    final_text = re.sub(r"\'ve", " 've ", final_text )
    final_text = re.sub(r"n\'t", " 't ", final_text )
    final_text = re.sub(r"\'re", " 're ", final_text )
    final_text = re.sub(r"\'d", " 'd ", final_text )
    final_text = re.sub(r"\'ll", " 'll ", final_text )
    final_text = re.sub(r",", " ", final_text )
    final_text = re.sub(r"\.", " ", final_text )
    final_text = re.sub(r"!", " ", final_text )
    final_text = re.sub(r"\(", " ( ", final_text )
    final_text = re.sub(r"\)", " ) ", final_text )
    final_text = re.sub(r"\?", " ", final_text )
    final_text = re.sub(r"\s{2,}", " ", final_text )
    return final_text

# %%
csvPath = "/Volumes/DD Thibault/sncf_DB/doc/engie/engie.csv"
scrapper = TextScrapper()
csv = scrapper.getTextCsv(csvPath)
labelList = []
data, test_data = train_test_split(csv,test_size=0.15)
print(test_data.iloc[[1]]["fileName"])
titles = []
label = []
docs=[]
for file in data.iloc:
    print(f"index {file.index} \n" )
    titles.append(file["fileName"])
    label.append(file["KidDocumentClass"])
    sentence  = cleanText(file["fileName"])
    docs.append(TaggedDocument(words=file["fileName"].split(), tags=file["KidDocumentClass"]))
    
model = gensim.models.doc2vec.Doc2Vec(vector_size=100, min_count=2, epochs=80)
model.build_vocab(docs)
model.train(docs, total_examples=model.corpus_count, epochs=80)
# Out:
# 3041    integration_fileUFsVwL
# Name: fileName, dtype: object
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# ...
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# index Index(['fileName', 'KidDocumentClass', 'fileSize', 'mimeType', 'owner',
#        'creationDate', 'KidFile'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 10>()
#      10 for file in data.iloc:
#      11     print(f"index {file.index}")
# ---> 12     titles.append(file["fileName"])
#      13     label.append(file["KidDocumentClass"])
#      14     sentence  = cleanText(file["fileName"])
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/pandas/core/series.py:1070, in Series._get_value(self, label, takeable)
#    1068 # Similar to Index.get_value, but we do not fall back to positional
#    1069 loc = self.index.get_loc(label)
# -> 1070 return self.index._get_values_for_loc(self, loc, label)
#
# KeyboardInterrupt:

# %%
newFile= "integratio filefMkFU4".split()
print(newFile)
new_vector = model.infer_vector(newFile)
print(new_vector)
similarity_doc = model.docvecs.most_similar([new_vector])
print(similarity_doc)
# Out:
# ['integratio', 'filefMkFU4']
# [ 7.76861329e-04 -3.29018524e-03  4.07167058e-03  1.89074758e-03
#  -4.32419125e-03  1.47073390e-03 -3.20030563e-03 -4.63459594e-03
#  -4.17660829e-03 -1.72183628e-03  2.24004220e-03  1.56795804e-03
#   1.72200857e-03 -2.34310143e-03 -2.51872488e-03  1.65744661e-03
#  -1.13889575e-04  1.49749871e-03 -5.71551325e-04  4.20914963e-03
#   4.23665624e-03  9.90259650e-05  2.00370839e-03  3.06847505e-03
#   3.99118289e-03 -3.40164610e-04 -4.16411227e-03 -3.31062381e-03
#  -1.17217598e-04  2.17846036e-03 -1.68072013e-03  3.20160622e-03
#  -1.35091657e-03 -4.69457870e-03  2.00896733e-03  8.95948382e-04
#   7.84490083e-04  8.53360863e-04 -2.29746825e-03 -1.92800397e-03
#   1.46106421e-03 -4.95326007e-03 -8.82520399e-04  3.70930554e-03
#   1.12376991e-03 -3.78974178e-03 -3.94000160e-03  3.47045786e-03
#   2.43580225e-03  3.83511838e-03  2.89001106e-03 -2.20582006e-03
#  -4.50933632e-03 -4.87776287e-03  2.74231005e-03 -3.77692468e-03
#  -1.35705527e-03  4.79111215e-03  1.59990252e-03 -4.82788030e-03
#  -4.21294617e-03 -4.12277586e-04  2.43350267e-04 -2.08096975e-03
#  -2.41712993e-03 -1.81025325e-03 -4.21566749e-03  4.53617098e-03
#  -1.37701037e-03 -1.52114814e-03  1.15552545e-03 -1.15916971e-03
#   1.25951890e-03 -1.61938521e-03  3.04777455e-03  1.08183210e-03
#  -3.65429814e-03 -1.95150438e-03 -2.40751961e-03  1.39815989e-03
#   2.15663313e-04 -1.66589802e-03  6.75972726e-04  3.08627542e-03
#  -4.04231250e-03  4.46409825e-03  2.39866087e-03  2.70664040e-03
#  -2.72960891e-03 -1.66981283e-03  3.57700163e-03  5.73598722e-04
#  -1.02607219e-03 -4.33304254e-03  1.28416484e-03  3.03353020e-03
#  -4.73465631e-03 -3.08700325e-03 -2.68839230e-03  1.35405303e-03]
# [('X', 0.23923315107822418), ('R', 0.16904647648334503), ('M', 0.16554418206214905), ('B', 0.15403124690055847), ('T', 0.14066347479820251), ('E', 0.08653420209884644), ('H', 0.05795741081237793), ('W', 0.024238992482423782), ('1', 0.023694857954978943), (';', 0.015523035079240799)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 10>()
#       8 new_file = []
#       9 new_file.append(TaggedDocument(words=word.split(), tags=test_data.iloc[[1]]["KidDocumentClass"]))
# ---> 10 model.build_vocab(new_file)
#      11 model.train(new_file, total_examples=model.corpus_count, epochs=80)
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/doc2vec.py:891, in Doc2Vec.build_vocab(self, corpus_iterable, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     888 report_values = self.prepare_vocab(update=update, keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, **kwargs)
#     890 report_values['memory'] = self.estimate_memory(vocab_size=report_values['num_retained_words'])
# --> 891 self.prepare_weights(update=update)
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/word2vec.py:850, in Word2Vec.prepare_weights(self, update)
#     848 # set initial input/projection and hidden weights
#     849 if not update:
# --> 850     self.init_weights()
#     851 else:
#     852     self.update_weights()
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/doc2vec.py:341, in Doc2Vec.init_weights(self)
#     340 def init_weights(self):
# --> 341     super(Doc2Vec, self).init_weights()
#     342     # to not use an identical rnd stream as words, deterministically change seed (w/ 1000th prime)
#     343     self.dv.resize_vectors(seed=self.seed + 7919)
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/word2vec.py:861, in Word2Vec.init_weights(self)
#     859 """Reset all projection weights to an initial (untrained) state, but keep the existing vocabulary."""
#     860 logger.info("resetting layer weights")
# --> 861 self.wv.resize_vectors(seed=self.seed)
#     863 if self.hs:
#     864     self.syn1 = np.zeros((len(self.wv), self.layer1_size), dtype=REAL)
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/keyedvectors.py:382, in KeyedVectors.resize_vectors(self, seed)
#     380 """Make underlying vectors match index_to_key size; random-initialize any new rows."""
#     381 target_shape = (len(self.index_to_key), self.vector_size)
# --> 382 self.vectors = prep_vectors(target_shape, prior_vectors=self.vectors, seed=seed)
#     383 self.allocate_vecattrs()
#     384 self.norms = None
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/keyedvectors.py:2123, in prep_vectors(target_shape, prior_vectors, seed, dtype)
#    2121 new_vectors -= 1.0  # [-1.0, 1.0)
#    2122 new_vectors /= vector_size
# -> 2123 new_vectors[0:prior_vectors.shape[0], 0:prior_vectors.shape[1]] = prior_vectors
#    2124 return new_vectors
#
# ValueError: could not broadcast input array from shape (2798,100) into shape (0,100)

# %%
similar_doc = model.docvecs.most_similar("727753347.pdf")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 similar_doc = model.docvecs.most_similar("727753347.pdf")
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/keyedvectors.py:842, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     839         weight[idx] = item[1]
#     841 # compute the weighted average of all keys
# --> 842 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     843 all_keys = [
#     844     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     845 ]
#     847 if indexer is not None and isinstance(topn, int):
#
# File /usr/local/Caskroom/miniconda/base/envs/knitiv/lib/python3.10/site-packages/gensim/models/keyedvectors.py:519, in KeyedVectors.get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     517         total_weight += abs(weights[idx])
#     518     elif not ignore_missing:
# --> 519         raise KeyError(f"Key '{key}' not present in vocabulary")
#     521 if(total_weight > 0):
#     522     mean = mean / total_weight
#
# KeyError: "Key '727753347.pdf' not present in vocabulary"
